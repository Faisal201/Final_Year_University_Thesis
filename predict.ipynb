# %%
import torch
import torch.nn as nn
from torchvision.transforms import transforms
import numpy as np
from torch.autograd import Variable
from torchvision.models import squeezenet1_1
import torch.functional as F
from io import open
import os
from PIL import Image
import pathlib
import glob
import cv2

# %%
train_path='E:/Final Year Thesis/Dataset/Modified_Dataset_Split/train'
pred_path='E:/Final Year Thesis/Dataset/Modified_Dataset_Split/test'

# %%
#categories
root=pathlib.Path(train_path)
classes=sorted([j.name.split('/')[-1] for j in root.iterdir()])

# %%
#CNN Network


class ConvNet(nn.Module):
    def __init__(self,num_classes=6):
        super(ConvNet,self).__init__()
        
        #Output size after convolution filter
        #((w-f+2P)/s) +1
        
        #Input shape= (256,3,150,150)
        
        self.conv1=nn.Conv2d(in_channels=3,out_channels=12,kernel_size=3,stride=1,padding=1)
        #Shape= (256,12,150,150)
        self.bn1=nn.BatchNorm2d(num_features=12)
        #Shape= (256,12,150,150)
        self.relu1=nn.ReLU()
        #Shape= (256,12,150,150)
        
        self.pool=nn.MaxPool2d(kernel_size=2)
        #Reduce the image size be factor 2
        #Shape= (256,12,75,75)
        
        
        self.conv2=nn.Conv2d(in_channels=12,out_channels=20,kernel_size=3,stride=1,padding=1)
        #Shape= (256,20,75,75)
        self.relu2=nn.ReLU()
        #Shape= (256,20,75,75)
        
        
        
        self.conv3=nn.Conv2d(in_channels=20,out_channels=32,kernel_size=3,stride=1,padding=1)
        #Shape= (256,32,75,75)
        self.bn3=nn.BatchNorm2d(num_features=32)
        #Shape= (256,32,75,75)
        self.relu3=nn.ReLU()
        #Shape= (256,32,75,75)
        
        
        self.fc=nn.Linear(in_features=75 * 75 * 32,out_features=num_classes)
        
        
        
        #Feed forwad function
        
    def forward(self,input):
        output=self.conv1(input)
        output=self.bn1(output)
        output=self.relu1(output)
            
        output=self.pool(output)
            
        output=self.conv2(output)
        output=self.relu2(output)
            
        output=self.conv3(output)
        output=self.bn3(output)
        output=self.relu3(output)
            
            
        #Above output will be in matrix form, with shape (256,32,75,75)
            
        output=output.view(-1,32*75*75)
            
            
        output=self.fc(output)
            
        return output

# %%
checkpoint=torch.load('best_checkpoint.model')
model=ConvNet(num_classes=6)
model.load_state_dict(checkpoint)
model.eval()
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(12, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (conv3): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (fc): Linear(in_features=180000, out_features=6, bias=True)
# )

# %%
#Transforms
transformer=transforms.Compose([
    transforms.Resize((150,150)),
    transforms.ToTensor(),  #0-255 to 0-1, numpy to tensors
    transforms.Normalize([0.5,0.5,0.5], # 0-1 to [-1,1] , formula (x-mean)/std
                        [0.5,0.5,0.5])
])

# %%
#prediction function
def prediction(img_path,transformer):
    
#     image=Image.open(img_path)
    image = Image.open(img_path).convert('RGB')
    
    image_tensor=transformer(image).float()
    
    
    image_tensor=image_tensor.unsqueeze_(0)
    
    if torch.cuda.is_available():
        image_tensor.cuda()
        
    input=Variable(image_tensor)
    
    
    output=model(input)
    
    index=output.data.numpy().argmax()
    
    pred=classes[index]
    
    return pred

# %%
images_path=glob.glob(pred_path+'/*.jpg')

# %%
pred_dict={}

for i in images_path:
    pred_dict[i[i.rfind('/')+1:]]=prediction(i,transformer)

# %%
pred_dict
# Out:
# {'test\\BACTERAILBLIGHT3_026.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_036.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_037.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_090.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_094.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_111.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_134.JPG': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_138.JPG': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_148.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_215.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_224.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT3_243.JPG': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT4_076.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT4_087.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT4_140.JPG': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT4_148.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT4_156.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT4_205.JPG': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT4_241.JPG': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_015.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_056.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_103.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_109.JPG': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_115.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_116.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_154.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_156.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_185.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_196.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_209.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_220.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_222.jpg': 'Bacterialblight',
#  'test\\BACTERAILBLIGHT5_258.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT1_010.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT1_025.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT1_035.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT1_043.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT1_080.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT1_094.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT1_135.JPG': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT1_145.JPG': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT1_152.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT1_244.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_021.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_037.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_066.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_070.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_082.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_109.JPG': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_114.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_116.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_127.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_144.JPG': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_162.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_180.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_183.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_195.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_210.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_212.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_214.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_245.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT2_252.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_018.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_025.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_040.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_049.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_064.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_072.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_095.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_108.JPG': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_112.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_134.JPG': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_179.JPG': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_191.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_201.jpg': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_236.JPG': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_240.JPG': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_243.JPG': 'Bacterialblight',
#  'test\\BACTERIALBLIGHT_254.jpg': 'Bacterialblight',
#  'test\\BLAST1_026.jpg': 'Blast',
#  'test\\BLAST1_036.jpg': 'Blast',
#  'test\\BLAST1_037.JPG': 'Blast',
#  'test\\BLAST1_090.jpg': 'Blast',
#  'test\\BLAST1_111.JPG': 'Blast',
#  'test\\BLAST1_134.jpg': 'Blast',
#  'test\\BLAST1_138.JPG': 'Blast',
#  'test\\BLAST1_148.JPG': 'Blast',
#  'test\\BLAST2_055.jpg': 'Blast',
#  'test\\BLAST2_064.JPG': 'Blast',
#  'test\\BLAST2_083.jpg': 'Brownspot',
#  'test\\BLAST3_020.jpg': 'Blast',
#  'test\\BLAST3_031.JPG': 'Blast',
#  'test\\BLAST3_083.jpg': 'Blast',
#  'test\\BLAST3_084.jpg': 'Blast',
#  'test\\BLAST3_092.jpg': 'Blast',
#  'test\\BLAST3_100.jpg': 'Blast',
#  'test\\BLAST4_025.jpg': 'Blast',
#  'test\\BLAST4_063.JPG': 'Blast',
#  'test\\BLAST4_104.jpg': 'Blast',
#  'test\\BLAST4_151.jpg': 'Blast',
#  'test\\BLAST4_157.jpg': 'Blast',
#  'test\\BLAST5_003.jpg': 'Blast',
#  'test\\BLAST5_004.jpg': 'Blast',
#  'test\\BLAST5_042.jpg': 'Blast',
#  'test\\BLAST5_044.jpg': 'Blast',
#  'test\\BLAST5_073.jpg': 'Blast',
#  'test\\BLAST5_084.jpg': 'Blast',
#  'test\\BLAST5_097.jpg': 'Blast',
#  'test\\BLAST5_108.jpg': 'Blast',
#  'test\\BLAST5_110.jpg': 'Bacterialblight',
#  'test\\BLAST5_146.JPG': 'Blast',
#  'test\\BLAST6_002.jpg': 'Blast',
#  'test\\BLAST6_017.jpg': 'Blast',
#  'test\\BLAST6_027.jpg': 'Blast',
#  'test\\BLAST6_035.JPG': 'Blast',
#  'test\\BLAST6_072.jpg': 'Blast',
#  'test\\BLAST6_086.jpg': 'Blast',
#  'test\\BLAST6_127.JPG': 'Blast',
#  'test\\BLAST6_137.JPG': 'Blast',
#  'test\\BLAST6_144.JPG': 'Blast',
#  'test\\BLAST7_076.jpg': 'Blast',
#  'test\\BLAST7_117.JPG': 'Blast',
#  'test\\BLAST7_133.JPG': 'Blast',
#  'test\\BLAST8_002.jpg': 'Blast',
#  'test\\BLAST8_006.jpg': 'Blast',
#  'test\\BLAST8_045.JPG': 'Blast',
#  'test\\BLAST8_050.JPG': 'Blast',
#  'test\\BLAST8_052.jpg': 'Blast',
#  'test\\BLAST8_063.JPG': 'Blast',
#  'test\\BLAST8_080.jpg': 'Blast',
#  'test\\BLAST8_098.jpg': 'Blast',
#  'test\\BLAST8_116.jpg': 'Blast',
#  'test\\BLAST8_119.JPG': 'Blast',
#  'test\\BLAST8_131.jpg': 'Blast',
#  'test\\BLAST8_146.JPG': 'Blast',
#  'test\\BLAST8_148.JPG': 'Blast',
#  'test\\BLAST8_150.JPG': 'Blast',
#  'test\\BLAST9_021.jpg': 'Blast',
#  'test\\BLAST9_028.jpg': 'Blast',
#  'test\\BLAST9_058.JPG': 'Blast',
#  'test\\BLAST9_065.JPG': 'Blast',
#  'test\\BLAST9_080.jpg': 'Blast',
#  'test\\BLAST9_089.jpg': 'Blast',
#  'test\\BLAST9_103.jpg': 'Blast',
#  'test\\BLAST9_104.jpg': 'Blast',
#  'test\\BLAST9_112.jpg': 'Blast',
#  'test\\BLAST9_136.JPG': 'Blast',
#  'test\\BLAST9_142.JPG': 'Blast',
#  'test\\BLAST9_148.JPG': 'Blast',
#  'test\\BLAST9_152.jpg': 'Blast',
#  'test\\BROWNSPOT1_026.jpg': 'Brownspot',
#  'test\\BROWNSPOT1_036.jpg': 'Brownspot',
#  'test\\BROWNSPOT1_037.jpg': 'Brownspot',
#  'test\\BROWNSPOT1_090.jpg': 'Brownspot',
#  'test\\BROWNSPOT1_094.jpg': 'Brownspot',
#  'test\\BROWNSPOT1_111.jpg': 'Brownspot',
#  'test\\BROWNSPOT1_134.jpg': 'Brownspot',
#  'test\\BROWNSPOT1_138.jpg': 'Brownspot',
#  'test\\BROWNSPOT1_148.jpg': 'Brownspot',
#  'test\\BROWNSPOT2_015.jpg': 'Brownspot',
#  'test\\BROWNSPOT2_024.jpg': 'Brownspot',
#  'test\\BROWNSPOT2_043.jpg': 'Brownspot',
#  'test\\BROWNSPOT2_140.jpg': 'Brownspot',
#  'test\\BROWNSPOT2_151.jpg': 'Brownspot',
#  'test\\BROWNSPOT3_003.jpg': 'Brownspot',
#  'test\\BROWNSPOT3_004.jpg': 'Brownspot',
#  'test\\BROWNSPOT3_012.jpg': 'Brownspot',
#  'test\\BROWNSPOT3_020.jpg': 'Brownspot',
#  'test\\BROWNSPOT3_069.jpg': 'Brownspot',
#  'test\\BROWNSPOT3_105.jpg': 'Brownspot',
#  'test\\BROWNSPOT3_143.jpg': 'Brownspot',
#  'test\\BROWNSPOT3_184.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_031.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_037.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_043.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_044.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_082.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_084.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_113.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_124.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_137.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_148.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_150.jpg': 'Brownspot',
#  'test\\BROWNSPOT4_186.jpg': 'Brownspot',
#  'test\\BROWNSPOT5_002.jpg': 'Brownspot',
#  'test\\BROWNSPOT5_017.jpg': 'Brownspot',
#  'test\\BROWNSPOT5_027.jpg': 'Brownspot',
#  'test\\BROWNSPOT5_035.jpg': 'Brownspot',
#  'test\\BROWNSPOT5_072.jpg': 'Brownspot',
#  'test\\BROWNSPOT5_086.jpg': 'Brownspot',
#  'test\\BROWNSPOT5_127.jpg': 'Brownspot',
#  'test\\BROWNSPOT5_137.jpg': 'Brownspot',
#  'test\\BROWNSPOT5_144.jpg': 'Brownspot',
#  'test\\BROWNSPOT6_036.jpg': 'Brownspot',
#  'test\\BROWNSPOT6_077.jpg': 'Brownspot',
#  'test\\BROWNSPOT6_093.jpg': 'Brownspot',
#  'test\\BROWNSPOT6_122.jpg': 'Brownspot',
#  'test\\BROWNSPOT6_126.jpg': 'Brownspot',
#  'test\\BROWNSPOT6_165.jpg': 'Brownspot',
#  'test\\BROWNSPOT6_170.jpg': 'Brownspot',
#  'test\\BROWNSPOT6_172.jpg': 'Brownspot',
#  'test\\BROWNSPOT6_183.jpg': 'Brownspot',
#  'test\\BROWNSPOT6_200.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_018.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_036.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_039.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_051.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_066.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_068.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_070.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_101.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_108.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_138.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_145.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_160.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_169.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_184.jpg': 'Brownspot',
#  'test\\BROWNSPOT7_192.jpg': 'Brownspot',
#  'test\\brownspot_orig_015.jpg': 'Brownspot',
#  'test\\brownspot_orig_028.jpg': 'Brownspot',
#  'test\\brownspot_orig_032.jpg': 'Brownspot',
#  'test\\brownspot_orig_054.jpg': 'Brownspot',
#  'test\\brownspot_orig_099.jpg': 'Brownspot',
#  'test\\brownspot_rotated_011.jpg': 'Brownspot',
#  'test\\brownspot_rotated_036.jpg': 'Brownspot',
#  'test\\brownspot_rotated_060.jpg': 'Brownspot',
#  'test\\brownspot_rotated_071.jpg': 'Brownspot',
#  'test\\brownspot_rotated_078.jpg': 'Brownspot',
#  'test\\brownspot_rotated_088.jpg': 'Brownspot',
#  'test\\brownspot_rotated_089.jpg': 'Brownspot',
#  'test\\TUNGRO1_026.jpg': 'Tungro',
#  'test\\TUNGRO1_036.jpg': 'Tungro',
#  'test\\TUNGRO1_037.jpg': 'Tungro',
#  'test\\TUNGRO1_090.jpg': 'Tungro',
#  'test\\TUNGRO1_094.JPG': 'Tungro',
#  'test\\TUNGRO1_111.JPG': 'Tungro',
#  'test\\TUNGRO1_134.JPG': 'Tungro',
#  'test\\TUNGRO1_138.JPG': 'Tungro',
#  'test\\TUNGRO1_148.JPG': 'Tungro',
#  'test\\TUNGRO1_215.JPG': 'Tungro',
#  'test\\TUNGRO1_224.JPG': 'Tungro',
#  'test\\TUNGRO1_243.JPG': 'Tungro',
#  'test\\TUNGRO2_063.jpg': 'Tungro',
#  'test\\TUNGRO2_074.jpg': 'Tungro',
#  'test\\TUNGRO2_094.JPG': 'Tungro',
#  'test\\TUNGRO2_126.JPG': 'Tungro',
#  'test\\TUNGRO2_127.JPG': 'Tungro',
#  'test\\TUNGRO2_135.JPG': 'Tungro',
#  'test\\TUNGRO2_143.JPG': 'Tungro',
#  'test\\TUNGRO2_161.JPG': 'Tungro',
#  'test\\TUNGRO2_192.JPG': 'Tungro',
#  'test\\TUNGRO2_228.JPG': 'Tungro',
#  'test\\TUNGRO2_266.JPG': 'Tungro',
#  'test\\TUNGRO3_030.jpg': 'Tungro',
#  'test\\TUNGRO3_076.jpg': 'Tungro',
#  'test\\TUNGRO3_077.jpg': 'Tungro',
#  'test\\TUNGRO3_083.jpg': 'Tungro',
#  'test\\TUNGRO3_089.jpg': 'Tungro',
#  'test\\TUNGRO3_090.jpg': 'Tungro',
#  'test\\TUNGRO3_128.JPG': 'Tungro',
#  'test\\TUNGRO3_130.JPG': 'Tungro',
#  'test\\TUNGRO3_159.JPG': 'Tungro',
#  'test\\TUNGRO3_170.JPG': 'Tungro',
#  'test\\TUNGRO3_183.JPG': 'Tungro',
#  'test\\TUNGRO3_194.JPG': 'Tungro',
#  'test\\TUNGRO3_196.JPG': 'Tungro',
#  'test\\TUNGRO3_232.JPG': 'Tungro',
#  'test\\TUNGRO3_248.JPG': 'Tungro',
#  'test\\TUNGRO3_263.JPG': 'Tungro',
#  'test\\TUNGRO3_273.JPG': 'Tungro',
#  'test\\TUNGRO4_004.jpg': 'Tungro',
#  'test\\TUNGRO4_041.jpg': 'Tungro',
#  'test\\TUNGRO4_055.jpg': 'Tungro',
#  'test\\TUNGRO4_096.JPG': 'Tungro',
#  'test\\TUNGRO4_106.JPG': 'Tungro',
#  'test\\TUNGRO4_113.JPG': 'Tungro',
#  'test\\TUNGRO4_205.JPG': 'Tungro',
#  'test\\TUNGRO4_246.JPG': 'Tungro',
#  'test\\TUNGRO4_253.JPG': 'Tungro',
#  'test\\TUNGRO4_262.JPG': 'Tungro',
#  'test\\TUNGRO5_110.jpg': 'Tungro',
#  'test\\TUNGRO5_114.jpg': 'Tungro',
#  'test\\TUNGRO5_125.JPG': 'Tungro',
#  'test\\TUNGRO5_15.jpg': 'Tungro',
#  'test\\TUNGRO5_154.jpg': 'Tungro',
#  'test\\TUNGRO5_156.jpg': 'Bacterialblight',
#  'test\\TUNGRO5_166.jpg': 'Tungro',
#  'test\\TUNGRO5_181.JPG': 'Tungro',
#  'test\\TUNGRO5_198.JPG': 'Tungro',
#  'test\\TUNGRO5_33.JPG': 'Tungro',
#  'test\\TUNGRO5_36.JPG': 'Tungro',
#  'test\\TUNGRO5_47.JPG': 'Tungro',
#  'test\\TUNGRO5_58.jpg': 'Tungro',
#  'test\\TUNGRO5_60.jpg': 'Tungro',
#  'test\\TUNGRO5_62.jpg': 'Tungro',
#  'test\\TUNGRO5_81.JPG': 'Tungro'}
